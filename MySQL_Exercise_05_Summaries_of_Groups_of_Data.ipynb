# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql USE dognitiondb
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name; # calculate in each group, from result, we can see there are 40 groups
# Out:
# 40 rows affected.
# [('1 vs 1 Game', Decimal('3.9206')),
#  ('3 vs 1 Game', Decimal('4.2857')),
#  ('5 vs 1 Game', Decimal('3.9272')),
#  ('Arm Pointing', Decimal('4.2153')),
#  ('Cover Your Eyes', Decimal('2.6741')),
#  ('Delayed Cup Game', Decimal('3.3514')),
#  ('Different Perspective', Decimal('2.7647')),
#  ('Expression Game', Decimal('4.0000')),
#  ('Eye Contact Game', Decimal('2.9372')),
#  ('Eye Contact Warm-up', Decimal('0.9632')),
#  ('Foot Pointing', Decimal('4.0093')),
#  ('Impossible Task Game', Decimal('3.0965')),
#  ('Impossible Task Warm-up', Decimal('0.2174')),
#  ('Inferential Reasoning Game', Decimal('4.5223')),
#  ('Inferential Reasoning Warm-up', Decimal('4.3066')),
#  ('Memory versus Pointing', Decimal('3.5584')),
#  ('Memory versus Smell', Decimal('4.2623')),
#  ('Navigation Game', Decimal('2.9841')),
#  ('Navigation Learning', Decimal('2.0303')),
#  ('Navigation Warm-up', Decimal('1.9805')),
#  ('Numerosity Warm-Up', Decimal('2.6173')),
#  ('One Cup Warm-up', Decimal('1.3693')),
#  ('Physical Reasoning Game', Decimal('3.8492')),
#  ('Physical Reasoning Warm-up', Decimal('1.6625')),
#  ('Self Control Game', Decimal('3.8519')),
#  ('Shaker Game', Decimal('4.6667')),
#  ('Shaker Warm-Up', Decimal('2.1818')),
#  ('Shared Perspective', Decimal('3.2778')),
#  ('Slide', Decimal('4.5111')),
#  ('Smell Game', Decimal('4.2857')),
#  ('Stair Game', Decimal('4.2857')),
#  ('Switch', Decimal('5.5676')),
#  ('Treat Warm-up', Decimal('0.7909')),
#  ('Turn Your Back', Decimal('3.1293')),
#  ('Two Cup Warm-up', Decimal('1.6737')),
#  ('Warm-Up', Decimal('1.2020')),
#  ('Watching', Decimal('2.4594')),
#  ('Watching - Part 2', Decimal('2.6570')),
#  ('Yawn Game', Decimal('2.8477')),
#  ('Yawn Warm-up', Decimal('2.0035'))]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests # MONTH() return a number representing the month
# FROM complete_tests
# GROUP BY Month; # group by the new created Month column
# Out:
# 12 rows affected.
# [('Delayed Cup Game', 1, 11068),
#  ('Yawn Warm-up', 2, 9122),
#  ('Yawn Warm-up', 3, 9572),
#  ('Physical Reasoning Game', 4, 7130),
#  ('Delayed Cup Game', 5, 21013),
#  ('Foot Pointing', 6, 23381),
#  ('Eye Contact Game', 7, 15977),
#  ('Memory versus Smell', 8, 13382),
#  ('Yawn Warm-up', 9, 19853),
#  ('Yawn Warm-up', 10, 39237),
#  ('Inferential Reasoning Warm-up', 11, 12652),
#  ('Inferential Reasoning Warm-up', 12, 10859)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month # group by multiple columns
# LIMIT 15;
# Out:
# 15 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at) # you can still group by derived fields
# LIMIT 15;
# Out:
# 15 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34)]

# %% [markdown]
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT gender, breed_group, COUNT(DISTINCT dog_guid) AS Num_Dogs
# FROM dogs
# GROUP BY breed_group, gender
# ORDER BY Num_Dogs DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075)]

# %% [markdown]
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT gender, breed_group, COUNT(DISTINCT dog_guid) AS Num_Dogs
# FROM dogs
# GROUP BY 1, 2 # 1 is gender, 2 is breed_group
# ORDER BY 3 DESC # 3 is Num_Dogs
# LIMIT 5;
# Out:
# 5 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736)]

# %% [markdown]
# ## The HAVING clause
#
# you can query subsets of aggregated groups using the HAVING clause. The expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT gender, breed_group, COUNT(DISTINCT dog_guid) AS Num_Dogs
# FROM dogs
# WHERE breed_group!="" AND breed_group IS NOT NULL AND breed_group<>"None" # <> is the same with !=
# GROUP BY 1, 2
# HAVING Num_Dogs>=1000 # Having should be after GROUP
# ORDER BY 3 DESC;
# Out:
# 8 rows affected.
# [('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075)]

# %% [markdown]
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %%sql
# SELECT breed_type, AVG(total_tests_completed) AS Avg_tests_completed, AVG(mean_iti_days) AS Avg_iti_days
# FROM dogs
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 10;
# Out:
# 4 rows affected.
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/default.py:470: Warning: (1292, "Truncated incorrect DOUBLE value: 'NaN'")
#   cursor.execute(statement, parameters)
# [('Popular Hybrid', 10.257530120481928, 1.9682781756219017),
#  ('Cross Breed', 9.945900537634408, 1.994688302855342),
#  ('Pure Breed', 9.871602824737856, 2.2176045095807226),
#  ("Mixed Breed/ Other/ I Don't Know", 9.54250850170034, 2.0993549515344747)]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# SELECT test_name, AVG(TIMESTAMPDIFF(hour, start_time, end_time)) AS Duration
# FROM exam_answers
# WHERE TIMESTAMPDIFF(hour, start_time, end_time)<=6000 AND TIMESTAMPDIFF(minute, start_time, end_time)>0
# GROUP BY 1
# ORDER BY Duration DESC;
# Out:
# 67 rows affected.
# [('Excitability', Decimal('806.1134')),
#  ('Attachment', Decimal('717.7429')),
#  ('Shy/Boldness', Decimal('716.3277')),
#  ('Sociability', Decimal('533.1124')),
#  ('Gender', Decimal('492.2347')),
#  ('Diet', Decimal('466.6369')),
#  ('Confinement', Decimal('354.5727')),
#  ('Social-Quiz', Decimal('347.9484')),
#  ('Activity', Decimal('342.8140')),
#  ('Purina-Only', Decimal('321.3333')),
#  ('Owner', Decimal('313.9195')),
#  ('Obedience', Decimal('270.8810')),
#  ('Surprise And Delight', Decimal('257.0656')),
#  ('Physical', Decimal('256.3563')),
#  ('Training', Decimal('250.0070')),
#  ('Perception', Decimal('203.4495')),
#  ('Purina', Decimal('184.4688')),
#  ('Partnership', Decimal('172.9626')),
#  ('Numerosity Warm-Up', Decimal('165.9070')),
#  ('Toys', Decimal('158.3235')),
#  ('Yawn Warm-up', Decimal('128.8406')),
#  ('Impossible Task Warm-up', Decimal('126.2923')),
#  ('Navigation Warm-up', Decimal('116.8423')),
#  ('Puzzles', Decimal('110.6307')),
#  ('Recall', Decimal('109.5281')),
#  ('Treat Warm-up', Decimal('108.0972')),
#  ('Delayed Cup Game', Decimal('107.7163')),
#  ('Emotions', Decimal('103.1011')),
#  ('Eye Contact Warm-up', Decimal('102.3775')),
#  ('Warm-Up', Decimal('88.4337')),
#  ('Environment', Decimal('58.4789')),
#  ('Set 1', Decimal('57.2917')),
#  ('Yawn Game', Decimal('51.9724')),
#  ('Foot Pointing', Decimal('47.6260')),
#  ('Inferential Reasoning Warm-up', Decimal('45.1241')),
#  ('Slide', Decimal('44.4545')),
#  ('Arm Pointing', Decimal('40.7247')),
#  ('One Cup Warm-up', Decimal('36.6924')),
#  ('Set 3', Decimal('36.0808')),
#  ('Memory versus Smell', Decimal('28.9546')),
#  ('Social', Decimal('27.4292')),
#  ('Smell Game', Decimal('23.0577')),
#  ('Watching', Decimal('16.9381')),
#  ('Physical Reasoning Warm-up', Decimal('15.9462')),
#  ('Memory versus Pointing', Decimal('14.7412')),
#  ('Inferential Reasoning Game', Decimal('14.4351')),
#  ('Navigation Learning', Decimal('6.4095')),
#  ('Stair Game', Decimal('5.1500')),
#  ('Watching - Part 2', Decimal('3.9864')),
#  ('Two Cup Warm-up', Decimal('3.5770')),
#  ('Switch', Decimal('3.3846')),
#  ('Shaker Warm-Up', Decimal('2.6250')),
#  ('Eye Contact Game', Decimal('2.2018')),
#  ('Navigation Game', Decimal('2.0360')),
#  ('Cover Your Eyes', Decimal('1.4367')),
#  ('Set 2', Decimal('1.2857')),
#  ('Turn Your Back', Decimal('1.2745')),
#  ('Physical Reasoning Game', Decimal('1.2535')),
#  ('Different Perspective', Decimal('0.7200')),
#  ('Impossible Task Game', Decimal('0.7050')),
#  ('Shared Perspective', Decimal('0.0000')),
#  ('Expression Game', Decimal('0.0000')),
#  ('Self Control Game', Decimal('0.0000')),
#  ('3 vs 1 Game', Decimal('0.0000')),
#  ('1 vs 1 Game', Decimal('0.0000')),
#  ('5 vs 1 Game', Decimal('0.0000')),
#  ('Shaker Game', Decimal('0.0000'))]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) AS Num_users
# FROM users
# WHERE country='US'
# GROUP BY state, zip
# ORDER BY state ASC, Num_Users DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('AE', '9128', 2),
#  ('AE', '9053', 1),
#  ('AE', '9107', 1),
#  ('AE', '9469', 1),
#  ('AE', '9845', 1),
#  ('AK', '99709', 3),
#  ('AK', '99507', 3),
#  ('AK', '99577', 2),
#  ('AK', '99501', 2),
#  ('AK', '99587', 1)]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) AS Num_users
# FROM users
# WHERE country='US'
# GROUP BY state, zip
# HAVING Num_Users>=5
# ORDER BY state ASC, Num_Users DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('AZ', '86303', 14),
#  ('AZ', '85718', 6),
#  ('AZ', '85254', 5),
#  ('AZ', '85260', 5),
#  ('AZ', '85711', 5)]
